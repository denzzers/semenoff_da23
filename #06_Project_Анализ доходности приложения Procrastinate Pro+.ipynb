# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Денис, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример из 3 проекта:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
#     <b>Привет, Саш!</b> Добавил подробное описание проекта и что нам предстоит выполнить, чтобы ответить на наши интересующие вопросы.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Денис, рад тебя видеть =)
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# # Анализ доходности приложения Procrastinate Pro+

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# ***
# Компания разработчик приложения `Procrastinate Pro+` последние месяцы терпит убытки, несмотря на большие вложения в рекламные кампании. Наша задача по проекту - почему происходит данная ситуация и по максимум постараться выдать маркетинговогу отделу рекомендации по улучшению ситуации.
#
# Для улучшения ситуации в копании приложения `Procrastinate Pro+` нам предстоит получить ответы на следующие вопросы:
# - откуда приходят пользователи и какими устройствами они пользуются;
# - сколько стоит привлечение пользователей из различных рекламных каналов;
# - сколько денег приносит каждый клиент;
# - когда расходы на привлечение клиента окупаются;
# - какие факторы мешают привлечению клиентов.
# ***
#
# **Последовательность действий**
#
# - Шаг 1. Загрузка данных и и подготовка их к анализу.
# - Шаг 2. Формирование функций для расчета и анализа LTV, ROI, удержания и конверсии.
# - Шаг 3. Исследовательский анализ данных:
#   - Оформление профилей пользователей.
#   - Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей?
#   - Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи?
#   - Какие каналы рекламных источников привлекли больше всего платящих пользователей?
# - Шаг 4. Маркетинг:
#   - Рассчет общей суммы расходов на маркетинг.
#   - Рассчет распределения трат по рекламным источникам.
#   - Визуализация динамики изменения расходов.
#   - Рассчет средней стоимости привлечения одного пользователя (САС) из кажждого источника.
# - Шаг 5. Оценка окупаемости рекламы.
# - Шаг 6. Общий вывод.
#
# ***
# **Описание данных**
#
# В нашем распоряжении есть данные о пользователях, привлечённых с 1 мая по 27 октября 2019 года:
# - Таблица `visits_info_short` — лог сервера с данными об их посещениях:
#   - `User Id` — уникальный идентификатор пользователя;
#   - `Region` — страна пользователя;
#   - `Device` — тип устройства пользователя;
#   - `Channel` — идентификатор источника перехода;
#   - `Session Start` — дата и время начала сессии;
#   - `Session End` — дата и время окончания сессии.
# - Таблица `orders_info_short` — выгрузка их покупок за этот период:
#   - `User Id` — уникальный идентификатор пользователя;
#   - `Event Dt` — дата и время покупки;
#   - `Revenue` — сумма заказа.
# - Таблица `costs_info_short.csv` — рекламные расходы:
#   - `dt` — дата проведения рекламной кампании;
#   - `Channel` — идентификатор рекламного источника;
#   - `costs` — расходы на эту кампанию.

# %%
# импортируем необходимые библиотеки для работы
from scipy import stats as st
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
import pandas as pd
from datetime import datetime, timedelta
import numpy as np

pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Шаг 1. Загрузка данных и и подготовка их к анализу.

# %% [markdown]
# ***
# Загрузим данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# Изучим данные и выполним предобработку. Поверим пропуски и дубликаты. Убедимся, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратим внимание на столбцы с датой и временем.
# ***

# %%
# сформируем список датасетов, предоставленных Заказчиком
visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

# %%
# сформируем список датасетов, предоставленных Заказчиком
datasets_yap = [
    '/datasets/visits_info_short.csv',
    '/datasets/orders_info_short.csv',
    '/datasets/costs_info_short.csv'
]

# %%
# сформируем список датасетов, предоставленных Заказчиком
datasets_local = [
    '/content/drive/MyDrive/datasets_YaP/visits_info_short.csv',
    '/content/drive/MyDrive/datasets_YaP/orders_info_short.csv',
    '/content/drive/MyDrive/datasets_YaP/costs_info_short.csv'
]

# %%
# сформируем список наименования датасетов
data_names = [
    'visits',
    'orders',
    'costs'
]

# %%
# прочитаем полученные датасеты
for i in range(len(data_names)):
  try:
    globals()[data_names[i]] = pd.read_csv(datasets_yap[i])
  except:
    globals()[data_names[i]] = pd.read_csv(datasets_local[i])

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Для подгрузки данных можно использовать конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %% [markdown]
# #### Обработка таблицы визитов пользователей

# %%
#выведем таблицу
visits
# Out:
#              User Id         Region   Device         Channel  \
# 0       981449118918  United States   iPhone         organic
# 1       278965908054  United States   iPhone         organic
# 2       590706206550  United States      Mac         organic
# 3       326433527971  United States  Android          TipTop
# 4       349773784594  United States      Mac         organic
# ...              ...            ...      ...             ...
# 309896  329994900775             UK       PC         LeapBob
# 309897  334903592310         France       PC  lambdaMediaAds
# 309898  540102010126        Germany       PC         organic
# 309899  308736936846        Germany      Mac         organic
# 309900  109329042535        Germany       PC  lambdaMediaAds
#
#               Session Start          Session End
# 0       2019-05-01 02:36:01  2019-05-01 02:45:01
# 1       2019-05-01 04:46:31  2019-05-01 04:47:35
# 2       2019-05-01 14:09:25  2019-05-01 15:32:08
# ...

# %%
#изучим информацию по таблице
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB

# %% [markdown]
# В инорфмации полученной имеются проблемы. которые необходимы устранить:
# - некорректное наименование колонок (необходимо привести к питонообразному виду);
# - колонки 'Session Start' и 'Session End' имеют неправильный тип данных (необходимо привести к типу datetime).

# %%
#приводим наименование колонок к правильному виду
visits.columns = visits.columns.str.replace(' ', '_').str.lower()

# %%
#выполняем проверку корректности наименования колонок
visits.columns
# Out:
# Index(['user_id', 'region', 'device', 'channel', 'session_start',
#        'session_end'],
#       dtype='object')

# %%
#приведем колонки 'Session Start' и 'Session End' к типу datetime
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

# %%
#выведим информацию по таблице и проверим выполненные преобразования
visits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  datetime64[ns]
#  5   session_end    309901 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(3)
# memory usage: 14.2+ MB

# %%
#выведим таблицу
visits.head(10)
# Out:
#         user_id         region   device         channel       session_start  \
# 0  981449118918  United States   iPhone         organic 2019-05-01 02:36:01
# 1  278965908054  United States   iPhone         organic 2019-05-01 04:46:31
# 2  590706206550  United States      Mac         organic 2019-05-01 14:09:25
# 3  326433527971  United States  Android          TipTop 2019-05-01 00:29:59
# 4  349773784594  United States      Mac         organic 2019-05-01 03:33:35
# 5   90242400005  United States   iPhone  RocketSuperAds 2019-05-01 07:14:52
# 6   43958116050  United States  Android         organic 2019-05-01 09:03:21
# 7  185365244969  United States   iPhone         organic 2019-05-01 09:37:03
# 8  446013509831  United States   iPhone  RocketSuperAds 2019-05-01 10:26:00
# 9  100970711362  United States      Mac          TipTop 2019-05-01 04:39:53
#
#           session_end
# 0 2019-05-01 02:45:01
# 1 2019-05-01 04:47:35
# 2 2019-05-01 15:32:08
# 3 2019-05-01 00:54:25
# ...

# %%
#проверим на наличие дубликатов колонки 'user_id', 'region', 'channel'
visits['channel'].unique()
# Out:
# array(['organic', 'TipTop', 'RocketSuperAds', 'YRabbit', 'FaceBoom',
#        'MediaTornado', 'AdNonSense', 'LeapBob', 'WahooNetBanner',
#        'OppleCreativeMedia', 'lambdaMediaAds'], dtype=object)

# %%
visits['region'].unique()
# Out:
# array(['United States', 'UK', 'France', 'Germany'], dtype=object)

# %%
#проверим наличие пустых значений
visits.isna().sum()
# Out:
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64

# %% [markdown]
# В таблице отсутствуют пустые значения

# %%
#проверим совпадает временной интервал в с предоставленным в задании проекта
print("Минимальная дата старта сессии:", visits['session_start'].min())
print("Максимальная дата старта сессии:", visits['session_start'].max())
# Out:
# Минимальная дата старта сессии: 2019-05-01 00:00:41
# Максимальная дата старта сессии: 2019-10-31 23:59:23

# %%
print("Минимальная дата окончания сессии:", visits['session_end'].min())
print("Максимальная дата окончания сессии:", visits['session_end'].max())
# Out:
# Минимальная дата окончания сессии: 2019-05-01 00:07:06
# Максимальная дата окончания сессии: 2019-11-01 01:38:46

# %% [markdown]
# В таблице имеются данные вываливающие за пределы предоставляемого периода, предлагаю посмотреть какой процент они составляют от общего числа записей.

# %%
visits_new = visits.query("session_start > '2019-10-29 23:59:59'")

# %%
delta = visits_new['user_id'].count() / visits['user_id'].count()
delta
# Out:
# 0.004801533392922256

# %% [markdown]
# Вывалившиеся данные составляют 0.4% от общего числа пользователей. Данный процент записей не повлияет на дальнейший анализ

# %% [markdown]
# <b>Итог:</b>
# В таблице visits были выполнены следующие действия:
# - приведены наименования колонок к питонообразному виду;
# - колонки 'session_start', 'session_end' приведены к типу datetime;
# - проверены дубликаты по колонкам 'channel', 'region'.
#
# Таблица готова к обработке.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# #### Обработка таблицы заказов пользователей

# %%
#выведем таблицу
orders
# Out:
#             User Id             Event Dt  Revenue
# 0      188246423999  2019-05-01 23:09:52     4.99
# 1      174361394180  2019-05-01 12:24:04     4.99
# 2      529610067795  2019-05-01 11:34:04     4.99
# 3      319939546352  2019-05-01 15:34:40     4.99
# 4      366000285810  2019-05-01 13:59:51     4.99
# ...             ...                  ...      ...
# 40207  651604369137  2019-10-31 16:19:07     4.99
# 40208  275341387049  2019-10-31 01:17:17     4.99
# 40209  374656616484  2019-10-31 06:17:29     4.99
# 40210  168548862926  2019-10-31 22:46:19     4.99
# 40211  329994900775  2019-10-31 13:29:06     4.99
#
# [40212 rows x 3 columns]

# %%
#изучим информацию по таблице
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB

# %% [markdown]
# В инорфмации полученной имеются проблемы, которые необходимы устранить:
# - некорректное наименование колонок (необходимо привести к питонообразному виду);
# - колонки 'Event Dt' имеет неправильный тип данных (необходимо привести к типу datetime).

# %%
#приводим наименование колонок к правильному виду
orders.columns = orders.columns.str.replace(' ', '_').str.lower()

# %%
#выполняем проверку корректности наименования колонок
orders.columns
# Out:
# Index(['user_id', 'event_dt', 'revenue'], dtype='object')

# %%
#приведем колонки 'Event Dt' к типу datetime
orders['event_dt'] = pd.to_datetime(orders['event_dt'])

# %%
#выведим информацию по таблице и проверим выполненные преобразования
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  datetime64[ns]
#  2   revenue   40212 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 942.6 KB

# %%
#выведим таблицу
orders.head(10)
# Out:
#         user_id            event_dt  revenue
# 0  188246423999 2019-05-01 23:09:52     4.99
# 1  174361394180 2019-05-01 12:24:04     4.99
# 2  529610067795 2019-05-01 11:34:04     4.99
# 3  319939546352 2019-05-01 15:34:40     4.99
# 4  366000285810 2019-05-01 13:59:51     4.99
# 5  129100331057 2019-05-01 01:56:28     4.99
# 6  626807144131 2019-05-01 02:39:21     4.99
# 7  914062168985 2019-05-01 02:02:18     4.99
# 8  769669137453 2019-05-01 03:39:47     4.99
# 9  434198630691 2019-05-01 18:16:50     5.99

# %%
#проверим наличие пустых значений
orders.isna().sum()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# В таблице отсутствуют пустые значения

# %%
#проверим на наличие дубликатов в таблице
duplic_ord = orders[orders.duplicated()]
duplic_ord.count()
# Out:
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64

# %% [markdown]
# В таблице отсутствуют явные дубликаты.

# %%
#проверим совпадает временной интервал в с предоставленным в задании проекта
print("Минимальная дата и время покупки:", orders['event_dt'].min())
print("Максимальная дата и время покупки:", orders['event_dt'].max())
# Out:
# Минимальная дата и время покупки: 2019-05-01 00:28:11
# Максимальная дата и время покупки: 2019-10-31 23:56:56

# %% [markdown]
# В таблице имеются записи с максимальной датой покупкой вываливающейся за предоставленный период для анализа. Проверим сколько процентов от общего числа записей эти данные составляют.

# %%
orders_new = orders.query("event_dt > '2019-10-29 23:59:59'")

# %%
delta_ord = orders_new['user_id'].count() / orders['user_id'].count()
delta_ord
# Out:
# 0.012061076295633145

# %% [markdown]
# Вывалившиеся данные составляют 1.2% от общего числа пользователей. Данный процент записей не повлияет на дальнейший анализ

# %% [markdown]
# <b>Итог:</b>
# В таблице orders были выполнены следующие действия:
# - приведены наименования колонок к питонообразному виду;
# - колонки 'event_dt', 'session_end' приведены к типу datetime.
#
# Таблица готова к обработке.

# %% [markdown]
# #### Обработка таблицы расходов на рекламу

# %%
#выведем таблицу
costs
# Out:
#               dt         Channel  costs
# 0     2019-05-01        FaceBoom  113.3
# 1     2019-05-02        FaceBoom   78.1
# 2     2019-05-03        FaceBoom   85.8
# 3     2019-05-04        FaceBoom  136.4
# 4     2019-05-05        FaceBoom  122.1
# ...          ...             ...    ...
# 1795  2019-10-23  lambdaMediaAds    4.0
# 1796  2019-10-24  lambdaMediaAds    6.4
# 1797  2019-10-25  lambdaMediaAds    8.8
# 1798  2019-10-26  lambdaMediaAds    8.8
# 1799  2019-10-27  lambdaMediaAds   12.0
#
# [1800 rows x 3 columns]

# %%
#изучим информацию по таблице
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   Channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %% [markdown]
# В инорфмации полученной имеются проблемы, которые необходимы устранить:
# - некорректное наименование колонок (необходимо привести к питонообразному виду);
# - колонки 'dt' имеет неправильный тип данных (необходимо привести к дате).

# %%
#приводим наименование колонок к правильному виду
costs.columns = costs.columns.str.lower()

# %%
#выполняем проверку корректности наименования колонок
costs.columns
# Out:
# Index(['dt', 'channel', 'costs'], dtype='object')

# %%
#приведем колонки 'Event Dt' к типу datetime
costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %%
#выведим информацию по таблице и проверим выполненные преобразования
costs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dt       1800 non-null   object
#  1   channel  1800 non-null   object
#  2   costs    1800 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 42.3+ KB

# %%
#выведим таблицу
costs.head(10)
# Out:
#            dt   channel  costs
# 0  2019-05-01  FaceBoom  113.3
# 1  2019-05-02  FaceBoom   78.1
# 2  2019-05-03  FaceBoom   85.8
# 3  2019-05-04  FaceBoom  136.4
# 4  2019-05-05  FaceBoom  122.1
# 5  2019-05-06  FaceBoom  118.8
# 6  2019-05-07  FaceBoom  101.2
# 7  2019-05-08  FaceBoom  100.1
# 8  2019-05-09  FaceBoom   93.5
# 9  2019-05-10  FaceBoom  104.5

# %%
#проверим наличие пустых значений
costs.isna().sum()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# В таблице отсутствуют пустые значения

# %%
#проверим на наличие дубликатов в таблице
duplic_cost = costs[costs.duplicated()]
duplic_cost.count()
# Out:
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# В таблице отсутствуют явные дубликаты.

# %%
#проверим совпадает временной интервал в с предоставленным в задании проекта
print("Минимальная дата проведения рекламной компании", costs['dt'].min())
print("Максимальная дата проведения рекламной компании:", costs['dt'].max())
# Out:
# Минимальная дата проведения рекламной компании 2019-05-01
# Максимальная дата проведения рекламной компании: 2019-10-27

# %% [markdown]
# В таблице все записи попадают в заданный интервал.

# %% [markdown]
# <b>Итог:</b>
# В таблице costs были выполнены следующие действия:
# - приведены наименования колонок к питонообразному виду;
# - колонка 'dt' приведена к дате.
#
# Таблица готова к обработке.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует проверка на дубликаты и пропуски. Так же нету вывода о качестве исходных данных. Поправишь, пожалуйста?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Добавил проверку дубликатов и пустых значений по таблицам, также добавил проверку правильно временного диапазона в предоставленных данных с периодом в задании.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
#
# Хорошо, основные действия по предобработке сделаны
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# * чтобы переименовать колонки, можно также использовать метод `rename()`
#
#
# * если мы только привели преобразование в строчные символы и заменили пробел на знак `_`, то мы можем использовать такой подход:
#
# `visits.columns = visits.columns.str.lower().str.replace(' ', '_')`
#
# также интересным является подход с использованием list comprehensions:
#
# `visits.columns = [x.lower().replace(' ', '_') for x in visits.columns.values]`
#
# * на стадии загрузки и подготовки данных к исследовательскому анализу, советую посмотреть на данные более детально, чтобы избежать невынужденных ошибок в дальнейшем. Чем большем мы знаем о данных - тем более корректны и обоснованы выглядят наши выводы. Такие проверки много времени не занимают, но зато мы можем лучше контролировать данные и их анализ. Например, мы можем:
#     - проверить временной интервал на соответствие условию проекта, а также на возможные ошибки (например, проверить случаи, когда окончание сессии было раньше, и так далее);
#     - для численных данных посмотреть на их статистические показатели и проверить их на наличие каких-то ошибок или аномалий (например, нули или отрицательные значения там, где они не должны быть).

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.

# %%
#зададим функцию для создания профилей пользователей
def get_profiles(visits, orders, costs, event_names=[]):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # добавляем флаги для всех событий из event_names
    for event in event_names:
        if event in events['event_name'].unique():
            profiles[event] = profiles['user_id'].isin(
                events.query('event_name == @event')['user_id'].unique()
            )

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
#зададим функцию для расчета конверсии
def get_conversion(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        purchases.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
#зададим функцию для расчета удержания
def get_retention(
    profiles,
    sessions,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        sessions[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
#зададим функцию для расчёта LTV и ROI

def get_ltv(
    profiles,
    purchases,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        purchases[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC,
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %%
#зададим функцию для визуализации LTV и ROI
def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
#зададим функцию для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
#зададим функцию для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )

    plt.tight_layout()
    plt.show()

# %%
#зададим функцию для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean()
    return df

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, все необходимые функции были заданы, можно приступать к расчета и анализу👀

# %% [markdown]
# ### Исследовательский анализ данных

# %% [markdown]
# Для проведения исследовательского анализа данных составим профили пользователей, по полученным профилям определим минимальную и максимальную даты привлечения пользователей.
#
# Далее в исследовательском анализе данных найдем ответы на следующие вопросы:
# - из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей?
# - какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи?
# - какие каналы рекламных источников привлечения больше всего приводят платящих пользователей?

# %% [markdown]
# #### Профили пользователей

# %%
#составим профили пользователей по функции get_profiles
profiles = get_profiles(
    visits, orders, costs
)

#выведим таблицу профилей пользователей с head и tail
display(profiles)
# Out:
#              user_id            first_ts       channel  device         region  \
# 0             599326 2019-05-07 20:58:57      FaceBoom     Mac  United States
# 1            4919697 2019-07-09 12:46:07      FaceBoom  iPhone  United States
# 2            6085896 2019-10-01 09:58:33       organic  iPhone         France
# 3           22593348 2019-08-22 21:35:48    AdNonSense      PC        Germany
# 4           31989216 2019-10-02 00:07:44       YRabbit  iPhone  United States
# ...              ...                 ...           ...     ...            ...
# 150003  999956196527 2019-09-28 08:33:02        TipTop  iPhone  United States
# 150004  999975439887 2019-10-21 00:35:17       organic      PC             UK
# 150005  999976332130 2019-07-23 02:57:06        TipTop  iPhone  United States
# 150006  999979924135 2019-09-28 21:28:09  MediaTornado      PC  United States
# 150007  999999563947 2019-10-18 19:57:25       organic  iPhone  United States
#
# ...

# %%
#определим минимальную дату привлечения пользователей
print("Минимальная дата привлечения пользователей:", profiles['first_ts'].min())
# Out:
# Минимальная дата привлечения пользователей: 2019-05-01 00:00:41

# %%
#определим максимальную дату привлечения пользователей
print("Максимальная дата привлечения пользователей:", profiles['first_ts'].max())
# Out:
# Максимальная дата привлечения пользователей: 2019-10-27 23:59:04

# %% [markdown]
# <b>Промежуточный итог:</b>
# - Сформированы профилей пользователей.
# - Определена минимальная дата привлечения пользователей -> 2019-05-01 00:00:41
# - Определена максимальная дата привлечения пользователей -> 2019-10-27 23:59:04
#
# Полученные минимальные и максимальные даты привлечения пользователей попадает в период вводных данных с 1 мая по 27 октября 2019 года.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Все верно!👍

# %% [markdown]
# #### Географическая принадлежность пользователей

# %% [markdown]
# <b>Основная задача.</b> Из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей?

# %%
#выведем проценты и округлим до двух знаков после запятой в python pandas
pd.options.display.float_format =lambda x:'{:.2%}'.format(x)

# %%
#определим географическую принадлежность пользователей сгруппиров данные по колонке 'region'
prof_regions = profiles.groupby('region').agg({'user_id': 'nunique'})
prof_regions = prof_regions.rename(columns={'user_id': 'unique_users'}).sort_values(by='unique_users', ascending=False)
prof_regions
# Out:
#                unique_users
# region
# United States        100002
# UK                    17575
# France                17450
# Germany               14981

# %% [markdown]
# В представленных данных для исследовательского анализа данных наибольшее количество пользователей находятся в США. Количество пользователй в США превосходит Европейский страны (Великобритания, Франция, Германия) почти в 5 раз.

# %%
#определим в какую страну приходится больше всего платящих пользователей
payer_prof_region = profiles.groupby('region').agg({'payer': ['sum', 'mean']})
payer_prof_region = payer_prof_region.rename(columns={'mean': 'ratio'})
payer_prof_region.columns = ['_'.join(col).strip() for col in payer_prof_region.columns.values]
payer_prof_region.sort_values(by='payer_ratio', ascending=False)
# Out:
#                payer_sum  payer_ratio
# region
# United States       6902        6.90%
# Germany              616        4.11%
# UK                   700        3.98%
# France               663        3.80%

# %% [markdown]
# Наибольшее количество пользователей также приходится на США - составляет 7%.
# Для каждой Европеской страны платящие пользователи составляют примерно 4%.

# %%
#объединим полученные таблицы по географической принадлежности
total_prof_region = prof_regions.merge(payer_prof_region, how='left', on='region')
total_prof_region
# Out:
#                unique_users  payer_sum  payer_ratio
# region
# United States        100002       6902        6.90%
# UK                    17575        700        3.98%
# France                17450        663        3.80%
# Germany               14981        616        4.11%

# %% [markdown]
# <b>Промежуточный итог:</b>
# - Наибольшее количество пользователей приходится на США -> 100002. Данный показатель больше в 5 раз, чем в Европейский странах.
# - Наибольше количество платящих пользователей приходится также на США -> 6,9%.
#
# Несмотря на больший разрыв в количестве пользователей по регионам, количество платящих пользователей в США больше в 1,75 - 2 раза.

# %% [markdown]
# #### Пользовательские устройства

# %% [markdown]
# <b>Основная задача.</b> Какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи?

# %%
#определим устроства, которые используют пользователи, сгруппиров данные по колонке 'device'
prof_device = profiles.groupby('device').agg({'user_id': 'nunique'})
prof_device = prof_device.rename(columns={'user_id': 'unique_users'}).sort_values(by='unique_users', ascending=False)
prof_device
# Out:
#          unique_users
# device
# iPhone          54479
# Android         35032
# PC              30455
# Mac             30042

# %% [markdown]
# В представленных данных для исследовательского анализа данных наибольшее количество пользователей используют IPhone (54479), следующим популярными устройствами являются пользователи с утройствами на платформе Android (35032).

# %%
#определим на какое устрйоство больше всего платящих пользователей
payer_prof_device = profiles.groupby('device').agg({'payer': ['sum', 'mean']})
payer_prof_device = payer_prof_device.rename(columns={'mean': 'ratio'})
payer_prof_device.columns = ['_'.join(col).strip() for col in payer_prof_device.columns.values]
payer_prof_device.sort_values(by='payer_ratio', ascending=False)
# Out:
#          payer_sum  payer_ratio
# device
# Mac           1912        6.36%
# iPhone        3382        6.21%
# Android       2050        5.85%
# PC            1537        5.05%

# %% [markdown]
# Несмотря на наименьшее количество пользователей, использующих устройство Mac, в данной группе наибольшее количество платящих пользователей - 6.36%. Платящих пользоватлей, использующие устройства на Android, несмотря на большее общее количество пользователй, составляет - 5.85%.

# %%
#объединим полученные таблицы по устройствам
total_prof_device = prof_device.merge(payer_prof_device, how='left', on='device')
total_prof_device
# Out:
#          unique_users  payer_sum  payer_ratio
# device
# iPhone          54479       3382        6.21%
# Android         35032       2050        5.85%
# PC              30455       1537        5.05%
# Mac             30042       1912        6.36%

# %% [markdown]
# <b>Промежуточный итог:</b>
# - Наибольшее количество пользователей используют Iphone -> 54479.
# - Наибольше количество платящих пользователей приходится на пользователей с Mac -> 6.36%.
#
# Несмотря на то, что пользователей с устройствами на платформе Android составляет 35032 и попадают на второе место по общему количеству, количество платящих пользователей сотавляет 5.85%.

# %% [markdown]
# #### Каналы привлечения пользователей

# %% [markdown]
# <b>Основная задача.</b> Какие каналы рекламных источников привлечения больше всего приводят платящих пользователей?

# %%
#определим каналы привлечения пользователей пользователи, сгруппиров данные по колонке 'channel'
prof_channel = profiles.groupby('channel').agg({'user_id': 'nunique'})
prof_channel = prof_channel.rename(columns={'user_id': 'unique_users'}).sort_values(by='unique_users', ascending=False)
prof_channel
# Out:
#                     unique_users
# channel
# organic                    56439
# FaceBoom                   29144
# TipTop                     19561
# OppleCreativeMedia          8605
# LeapBob                     8553
# WahooNetBanner              8553
# RocketSuperAds              4448
# MediaTornado                4364
# YRabbit                     4312
# AdNonSense                  3880
# lambdaMediaAds              2149

# %% [markdown]
# Наибольшее количество пользователей приходит без дополнительных привлечений по каналу organic.

# %%
#определим по какому каналу приходит больше всего платящих пользователей
payer_prof_channel = profiles.groupby('channel').agg({'payer': ['sum', 'mean']})
payer_prof_channel = payer_prof_channel.rename(columns={'mean': 'ratio'})
payer_prof_channel.columns = ['_'.join(col).strip() for col in payer_prof_channel.columns.values]
payer_prof_channel.sort_values(by='payer_ratio', ascending=False)
# Out:
#                     payer_sum  payer_ratio
# channel
# FaceBoom                 3557       12.20%
# AdNonSense                440       11.34%
# lambdaMediaAds            225       10.47%
# TipTop                   1878        9.60%
# RocketSuperAds            352        7.91%
# WahooNetBanner            453        5.30%
# YRabbit                   165        3.83%
# MediaTornado              156        3.57%
# LeapBob                   262        3.06%
# OppleCreativeMedia        233        2.71%
# organic                  1160        2.06%

# %% [markdown]
# Несмотря на то, что пользователей по каналу organic приходит наибольшее количество, платящих клиентов по данному каналу приходит наименьшее количество - 2.06%.

# %%
#объединим полученные таблицы по каналам
total_prof_channel = prof_channel.merge(payer_prof_channel, how='left', on='channel')
total_prof_channel
# Out:
#                     unique_users  payer_sum  payer_ratio
# channel
# organic                    56439       1160        2.06%
# FaceBoom                   29144       3557       12.20%
# TipTop                     19561       1878        9.60%
# OppleCreativeMedia          8605        233        2.71%
# LeapBob                     8553        262        3.06%
# WahooNetBanner              8553        453        5.30%
# RocketSuperAds              4448        352        7.91%
# MediaTornado                4364        156        3.57%
# YRabbit                     4312        165        3.83%
# AdNonSense                  3880        440       11.34%
# lambdaMediaAds              2149        225       10.47%

# %% [markdown]
# <b>Промежуточный итог:</b>
# - Фаворитами являются источники FaceBoom c 12,2% платящих пользователей, TipTop c 9.6%. Оба этих источника и привлекают наибольшее количество клиентов.
# - Каналы AdNonSense и lambdaMediaAds которые хоть и являются отстающими по привлечению пользователей, но попадают в тройку лидерова по проценту конвертации их плательщиков -> 11,34% и 10,47%.

# %%
#отменяем стандарт оформления в процентах для float
pd.reset_option('^display.', silent=True)

# %% [markdown]
# <b>Выводы исследовательского анализа данных:</b>
# 1. Были построены пользовательски профили. По полученным минимальным и максимальным датам привлечения был подтвержден полученный период в исходных данных -> c 1 мая по 27 октября 2019 года.
# 2. Провели исследовательских анализ данных пользователей Procrastinate Pro+:
#         - наибольшее количество пользователей проживает в США;
#         - наибольшее платящих клиентов используют устройства компании Apple -> Mac и IPhone;
#         - также наибольщее количество пользователей использует IPhone;
#         - наилучшими каналами привлечения траффика пользователей проходит через FaceBoom и TipTop, конвертация их составляет 12,2% и 9,6%;
#         - каналы AdNonSense и lambdaMediaAds которые хоть и являются отстающими по привлечению пользователей, но попадают в тройку лидерова по проценту конвертации их плательщиков -> 11,34% и 10,47%.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# В целом в данном разделе был проведен хороший анализ данных - мы посмотрели на базовые значения конверсии пользователей в покупатели по регионам, устройствам и каналу привлечения, определили основной рынок. Получается, что больше всего приходит пользователей из США и они лучше других конвертируется. При этом большая часть пользователей заходит с мобильных устройств, это тоже стоит отметить. Также, мы можем сказать, что наибольшую конверсию имеют пользователи, которые пользуются Mac, а затем следуют пользователи iPhone, т.е. мы можем сказать, что в целом пользователи Apple имеют лучшую конверсию в покупателей. Возможно, тут есть плюсы ApplePay.

# %% [markdown]
# ### Маркетинг
#
# В разделе маркетинга нам необходимо ответить на следующие вопросы:
# - Какая общая сумма расходов на маркетинг?
# - Как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник?
#
# А также:
# - Построим визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику.
# - Узнаем, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника.

# %% [markdown]
# #### Общая сумма расходов на маркетинг

# %%
#отфильтруем профили пользователей, исключим канал 'organic'
profiles = profiles.query("channel != 'organic'")

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совершенно верно, поскольку мы за них ничего не платим,  а нам нужно изучить именно окупаемость рекламы.
# </div>

# %%
#выполним расчет общей суммы затрат на маркетинг
sum_costs = round(costs['costs'].sum(), 2)
print('Общая сумма расходов на маркетинг:', sum_costs, '$')
# Out:
# Общая сумма расходов на маркетинг: 105497.3 $

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
#
# Здорово, что округлили до двух знаков после запятой.

# %% [markdown]
# #### Распределение затрат по рекламным источникам

# %%
#определим затраты по каждому рекламному источнику
cost_channel = costs.groupby('channel').agg({'costs': 'sum'}).sort_values(by='costs', ascending=False)
cost_channel
# Out:
#                        costs
# channel
# TipTop              54751.30
# FaceBoom            32445.60
# WahooNetBanner       5151.00
# AdNonSense           3911.25
# OppleCreativeMedia   2151.25
# RocketSuperAds       1833.00
# LeapBob              1797.60
# lambdaMediaAds       1557.60
# MediaTornado          954.48
# YRabbit               944.22

# %% [markdown]
# Наибольшие затраты на привлечение новых пользователей приходятся на:
# - TipTop -> 54751
# - FaceBoom -> 32445
#
# Данные затраты составляют примерно 80% от общей суммы затрат на маркетинг приложения Procrastinate Pro+.
# При этом каналы AdNonSense и lambdaMediaAds, которые находятся в лидерах по привлечению платных пользователей из общей суммы привлекают всего примерно 5% расходов от общей суммы на маркетинг.

# %% [markdown]
# #### Визуализация динамики изменения расходов

# %%
costs['dt'] = pd.to_datetime(costs['dt'], errors ='coerce')
#создадим колонку с номером недели
costs['week_numb'] = costs['dt'].dt.isocalendar().week
#создадим колонку с обозначением месяца
costs['month'] = costs['dt'].dt.month
#проверим полученный результат и выведим первые 10 строк dataset
costs.head(10)
# Out:
#           dt   channel  costs  week_numb  month
# 0 2019-05-01  FaceBoom  113.3         18      5
# 1 2019-05-02  FaceBoom   78.1         18      5
# 2 2019-05-03  FaceBoom   85.8         18      5
# 3 2019-05-04  FaceBoom  136.4         18      5
# 4 2019-05-05  FaceBoom  122.1         18      5
# 5 2019-05-06  FaceBoom  118.8         19      5
# 6 2019-05-07  FaceBoom  101.2         19      5
# 7 2019-05-08  FaceBoom  100.1         19      5
# 8 2019-05-09  FaceBoom   93.5         19      5
# 9 2019-05-10  FaceBoom  104.5         19      5

# %%
#создадим графики затрат на маркетинг по месяцам и неделям
ax1 = costs.pivot_table(index=['month'], columns='channel', values='costs', aggfunc='sum').plot(
    ax=plt.subplot(1, 2, 1),
    figsize=(22, 10),
    grid=False,
)

ax1.grid(which='major', color = 'k')
ax1.minorticks_on()
ax1.grid(which='minor', color = 'gray', linestyle = ':')

plt.title('График изменения затрат в разбивке по каналам по месяца')
plt.xlabel('Месяц')
plt.ylabel('Затраты')

ax2 = costs.pivot_table(index=['week_numb'], columns='channel', values='costs', aggfunc='sum').plot(
    ax=plt.subplot(1, 2, 2),
    figsize=(22, 10),
    grid=False,
)

ax2.grid(which='major', color = 'k')
ax2.minorticks_on()
ax2.grid(which='minor', color = 'gray', linestyle = ':')

plt.title('График изменения затрат в разбивке по каналам по неделям')
plt.xlabel('Неделя')
plt.ylabel('Затраты')
plt.show()

# %% [markdown]
# По графикам мы наблюдаем постоянный рост затрат на два канала TipTop и FaceBoom. На протяжении всего предоставленного периода данные затраты росли, например, на рекламный канал TipTop затраты увеличились с почти 3000 (май месяц) до 12500 (сентября месяц) долларов.
#
# Также по графику можно наблюдать следующие тенденции:
# - начиная с июня месяца (6) в конце каждого месяца, предоставленного в периоде, затраты на рекламу по каналам падали;
# - аналогичная ситуация и с началом каждого месяца - затраты на рекламе резко увеличивались;
# - наиболее затратным является период является конец сентября.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, в данном шаге нам нужно визулизировать динамику расходов по каналам (2 графика: по месяцам и по неделям). Добавишь, пожалуйста?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Разбил график на два графика по месяцам и неделям.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Отличные и наглядные графики 👍
#
# Здорово, когда они подписаны. Так быстрее понять о чем идёт речь на нём.
#
# </div>

# %% [markdown]
# #### Средняя стоимость привлечения пользователя (CAC)

# %%
#рассчитаем среднюю стоимость привлечения пользователя на весь период
cac_full = round(sum_costs / profiles['user_id'].count(), 2)
print('Средняя стоиомсть привлечения пользователя за весь период ->', cac_full)
# Out:
# Средняя стоиомсть привлечения пользователя за весь период -> 1.13

# %%
#соединим сводные таблицы 'cost_channel' и 'prof_channel' для расчета среднего (CAC) по каналам
channel_cac = cost_channel.merge(prof_channel['unique_users'], on=['channel'], how='left')
channel_cac
# Out:
#                        costs  unique_users
# channel
# TipTop              54751.30         19561
# FaceBoom            32445.60         29144
# WahooNetBanner       5151.00          8553
# AdNonSense           3911.25          3880
# OppleCreativeMedia   2151.25          8605
# RocketSuperAds       1833.00          4448
# LeapBob              1797.60          8553
# lambdaMediaAds       1557.60          2149
# MediaTornado          954.48          4364
# YRabbit               944.22          4312

# %%
#посчитаем среднюю стоимость привлечения пользователя по каналам и добавим в сводную таблицу 'channel_cac'
channel_cac['cac'] = round(channel_cac['costs'] / channel_cac['unique_users'], 2)
channel_cac
# Out:
#                        costs  unique_users   cac
# channel
# TipTop              54751.30         19561  2.80
# FaceBoom            32445.60         29144  1.11
# WahooNetBanner       5151.00          8553  0.60
# AdNonSense           3911.25          3880  1.01
# OppleCreativeMedia   2151.25          8605  0.25
# RocketSuperAds       1833.00          4448  0.41
# LeapBob              1797.60          8553  0.21
# lambdaMediaAds       1557.60          2149  0.72
# MediaTornado          954.48          4364  0.22
# YRabbit               944.22          4312  0.22

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Неплохо бы посчитать средний САС по проекту
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Если я тебя правильно понял, то я же вроде сделал это в ячейке 66 или ты про что-то другое?</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Совершенно верно. Здорово, что рассчитал средний САС. Молодец)
#
# </div>

# %% [markdown]
# Наибольшая средняя стоимость привлечения пользователя приходится на канал TipTop -> 2.8 доллара. По полученным данным можно обратить внимание, что значение данного канала превышает среднюю стоимость остальных каналов больше чем в 2 раза.
#
# Построим график истории изменения CAC за весь период.

# %%
#построим график истории изменений CAC по каналам привлечения
profiles.pivot_table(
    index='dt', columns='channel', values='acquisition_cost', aggfunc='mean'
).plot(grid=True, figsize=(20, 8))
plt.ylabel('CAC, $')
plt.xlabel('Дата привлечения')
plt.title('Динамика САС по каналам привлечения')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что визуализировал динамику САС по каналам
# </div>

# %% [markdown]
# На графике истории изменения CAC снова в глаза бросается канал привлечения TipTop. На протяжении всего периода данный канал все больше на себя привлекает затрат по привлечению пользователей, в то время как остальные каналы находятся в одном своем ценовом диапазоне за пользователя.

# %% [markdown]
# <b>Выводы по проведенному маркетингу в предоставленный период:</b>
# - Общая сумма расходов на маркетинг составила 105497.3 долларов;
# - Наибольшую часть затрат по маркетингу (80% от общей суммы) направили на каналы TipTop -> 54751 и FaceBoom -> 32445;
# - Рост затрат постоянно происходил также у каналов TipTop и FaceBoom;
# - Необходимо провести оценку окупаемости рекаламы по каналу TipTop, так как средняя стоимость привлечения клиента составляет 2.8 доллара, что больше чем 2 раза стоимости привлечения по другим каналам, а также и по одном из лидеров по затратам FaceBoom. Данная тенденция прослеживается и на всем периоде истории измении CAC, стоимость привлечения пользователя по каналу TipTop с каждым месяцем возрастает.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Наиболее дорогостоящим каналом привлечения пользователей является TipTop, однако количество и доля платящих пользователей, приходящих с этого источника, не так высоки. Это можно объяснить молодой аудиторией TipTop'a и, соответственно, не очень высокой их платежеспособностью.
#
# </div>

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %% [markdown]
# #### Общая окупаемость рекламы

# %%
#зададим момент анализа данных
observation_date = datetime(2019, 11, 1).date()
#зададим горизонт анализа данных
analysis_horizon = 14

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history  = get_ltv(
    profiles, orders, observation_date, analysis_horizon
)

#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon)

# %% [markdown]
# По полученным графикам можно сделать следующие выводы:
# - ROI за последние 14 дней достигает 80% и не доходит окупаемости рекламы;
# - также за последние 14 дней ROI просаживается значительно ниже линии окупаемости, это может говорить о том, что выстроенная бизнес-стратегия не работает как надо;
# - стоимость привлечения пользователей постоянно растет, из чего можно сделать вывод, что бюджетирование рекламы идет постоянное.
#
# Для полноты картины необходимо провести анализ окупаемости с разбивкой по устройствам, странам и каналам привлечения пользователей.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Логика анализа верная, согласен с выводом. Наблюдаем, что динамика ROI за лайфтайм падает. При относительно стабильной динамике LTV, динамика САС растёт с мая по конец октября. Эту закономерность мы наблюдаем в динамике ROI, что при сильном увеличении САС, в равной степени падает динамика ROI пользователей.
# </div>

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по устройствам

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history  = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)

#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon, window=14)

# %% [markdown]
# По полученным графикам можно сделать следующие выводы:
# - для пользователей всех устройств стоимость их привлечения растет: в данном росте можно заметить аномально высокие затраты на пользователей устройств Apple - IPhone и Mac;
# - ROI для пользователей Apple при высоких затратах на рекламу не окупается, в такой же ситуации находятся пользователи, использующие устройства на Android;
# - Наиболее стабильные пользователи на PC, рост стоимости их привлечения не сильно повысился, при этом это единственные пользователи, которые окупаются;
#
# Основной вывод по данному анализу можно сделать следующий:
# - Стоимость привлечения основных платящих пользователей. Таковыми являются пользователи Apple, которых по сравнению с другими пользователями больше, а также среди них находятся основная часть платящих пользователей. Тем самым больше всего негативно влияют на окупаемость.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# С окупаемостью проблемы по всем устройствам кроме PC. Это значит, что у нас, по крайней мере, нет технических проблем, влияющих на монетизацию;
# </div>

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по каналам привлечения

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history  = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=['channel']
)

#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon, window=14)

# %% [markdown]
# По полученным графикам можно сделать следующие выводы:
# - неокупаемыми источниками рекламы являются следующие каналы: TipTop, AdNonSense, FaceBoom. При этом как мы выяснили на Шаге 4 каналы TipTop и FaceBoom являются лидерами по количеству привлеченных пользователей;
# - стоимость привлечения по каналу TipTop постоянно растет и выросла практически 3.5 раза, при этом ROI у данного канала самый худший;
# - остальные каналы привлечения окупаемости, а также у всех каналов хорошая динамика удержания пользователей.
#
# Из выше представленных выводов можно сказать, что пользователи, пришедшие по каналу TipTop, оказывают негативное влиянение на окупаемость.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, действительно, есть проблемы с каналом TipTop, видим значительный рост затрат на привлечение.
# </div>

# %% [markdown]
# #### Окупаемость рекламы с разбивкой по странам

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history  = get_ltv(
    profiles, orders, observation_date, analysis_horizon, dimensions=['region']
)

#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon, window=14)

# %% [markdown]
# По полученным графикам можно сделать следующие выводы:
# - аналогичная картина, как и с устройствами, наблюдается и со странами. Пользователи из США, которых мы определили как самую большую когорту пользователей, по сравнению с Европейскими странами. Окупаемость пользователей из США отсутствует при том, что количество привлеченных инвестиций достигает максимальных значений.
# - Стоимость привлечения клиентов в европейских странах наоборот с июня месяца уменьшилась, но при этом все эти инвестиции окупаются.
#
# По итогу можно сделать вывод, что пользователи из США и инвестиции на данный регион оказывает наибольшее негативное влияние, чем европейские страны.
#
# Для полноты картины проанализируем профили пользователей из США отдельно, так как это является самой большой когортой.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Все верно. Нужно разбираться детальнее с рекламой в США, тем более, что это наш основной рынок.

# %% [markdown]
# #### Окупаемость рекламы по региону США

# %%
#отфильтруем таблицу профилей по региону - США
usa_profiles = profiles.query("region == 'United States'")

# %% [markdown]
# ##### С разбивкой по девайсам

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    usa_profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)
#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon, window=14)

# %% [markdown]
# По полученным графикам опасения подтверждаются, так как рекламные действия в выделенном нами регионе приносят приложению убытки:
# - ROI всех когорт по девайсам не достигают окупаемости, при этом инвестиции на привлечение пользователей растут постоянно на всем периоде:
#         - Apple, Mac, IPhone достигают 70%;
#         - Android показыаются наилучший результат - достигает почти 80%.

# %% [markdown]
# ##### С разбивкой по каналам привлечения

# %%
#высчитаем LTV и ROI с помощью функции get_ltv
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(
    usa_profiles, orders, observation_date, analysis_horizon, dimensions=['channel']
)
#построим графики с помощью функции plot_ltv_roi
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, analysis_horizon, window=14)

# %% [markdown]
# Каналов в США используется меньше, чем для общего числа регионов. Основными проблемными являются также как и в общей таблице профилей, включая европейские страны, TipTop и FaceBoom, также не достигают порога окупаемости.
# При этом также наблюдается рост привлечения инвестиций на рекламные расходны по каналу TipTop в 3.5 раза.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# А вот это...очень грамотный шаг для продуктового аналитика. Здорово, что рассмотрел США дополнительно

# %% [markdown]
# #### Общая конверсия и удержание пользователей

# %% [markdown]
# ##### С разбивкой по устройствам

# %%
#построим графики конверсии пользователей и ее динамики
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)
plot_conversion(conversion_grouped, conversion_history, analysis_horizon)

# %% [markdown]
# Наилучшая конверсия, которая достигает 8.5%, приходится на пользователей продукции Apple (Mac, IPhone).
# Самым худший показатель у пользователей с устройствами PC, который достигает 6.5%.

# %%
# изучим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, analysis_horizon, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Самое хорошее удержание по графикам наблюдается у пользователей с утройством PC, при этом самые платящие клиенты, а именно Mac и IPhone, имеют самое худшее удержание пользователей. Разница удержания небольшая, но ситуация с удержанием должна быть ровным счетом наоборот.

# %% [markdown]
# ##### С разбивкой по регионам

# %%
#построим графики конверсии пользователей и ее динамики
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, analysis_horizon, dimensions=['region']
)
plot_conversion(conversion_grouped, conversion_history, analysis_horizon)

# %% [markdown]
# Конверсия в США достигает почти 10%, в то время как у европейских стран конверсия достигает только 5%.
# Ранее мы определили, что пользователей из США больше всего, следовательно, можно сделать предварительный вывод, что есть вероятность улучшения показателей по данной когорте, что позитивно сложится для приложения.

# %%
# изучим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, analysis_horizon, dimensions=['region']
)

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Несмотря на хорошую конверсию у пользователей из США, удержание данной когорты платящих пользователей мала и достигает всего лишь 10%, в то время как показатели удержания платящих пользователей в еропейских странах достигает 15-19%. Динамика удержания пользователей США также ничтожна мала.
#
# Посему можно сделать вывод, что если возможно достичь показателей удержания как у европейских стран, то необходимо рассмотреть действия для удержания пользователей из США.

# %% [markdown]
# ##### С разбивкой по каналам привлечения

# %%
#построим графики конверсии пользователей и ее динамики
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    profiles, orders, observation_date, analysis_horizon, dimensions=['channel']
)
plot_conversion(conversion_grouped, conversion_history, analysis_horizon)

# %% [markdown]
# Лидером по конверсии и по ее динамике, а именно она стабильна на всем периоде, является FaceBoom.
# Также можно обратить внимание, что самый привлекаемым по инвестициям канал TipTop находится на 4м месте по конверсии и достигает 11%.

# %%
# изучим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    profiles, visits, observation_date, analysis_horizon, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Аналогичная ситуация и с регионами, лидер конверсии находится на последнем месте по удержанию и динамике удержания. Хорошие показатели как конверсии, так и ее удержания, принадлежат lambadaMediaAds. Следует обратить внимание на работу с каналом FaceBoom.
#
# Далее посмотрим конверсию и ее удержание по профилям региона США.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен с интерпретацией результатов. Проблемные источники определены верно.

# %% [markdown]
# #### Конверсия и удержание пользователей по региону США

# %% [markdown]
# ##### С разбивкой по устройствам

# %%
#построим графики конверсии пользователей и ее динамики
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    usa_profiles, orders, observation_date, analysis_horizon, dimensions=['device']
)
plot_conversion(conversion_grouped, conversion_history, analysis_horizon)

# %% [markdown]
# Конверсия пользователей из США по устройствам находится в близком друг от друга диапазоне. С небольшим отрывом пользователи на платформе Android - достигает 10.5%.

# %%
# изучим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    usa_profiles, visits, observation_date, analysis_horizon, dimensions=['device']
)

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Удержание как и конверсия без изменений и пользователи на всех устройствах также находятся в одном диапазоне.

# %% [markdown]
# ##### С разбивкой по каналам привлечения

# %%
#построим графики конверсии пользователей и ее динамики
conversion_raw, conversion_grouped, conversion_history = get_conversion(
    usa_profiles, orders, observation_date, analysis_horizon, dimensions=['channel']
)
plot_conversion(conversion_grouped, conversion_history, analysis_horizon)

# %%
# изучим удержание
retention_raw, retention_grouped, retention_history = get_retention(
    usa_profiles, visits, observation_date, analysis_horizon, dimensions=['channel']
)

plot_retention(retention_grouped, retention_history, analysis_horizon)

# %% [markdown]
# Общая картина по конверсии и удержанию в регионе США очень похожа на общую картину по каналам привлечения. Лидеры FaceBoom ко конверсии находятся на последнем месте по удержании и ее динамике.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо, анализ конверсии и удержания корректен

# %% [markdown]
# <b>Выводы по оценке окупаемости рекламы:</b>
# - лидеры по конверсии каналов привлечения пользователей:
#         - FaceBoom;
#         - AdNonSense;
#         - lambdaMediaAds;
#         - TipTop.
# - при этом FaceBoom показывает наихудшие показатели по удержанию.
# - аналогичная ситуация и с разбивкой по регионам и устройствам:
#         - наилучшие показатели конверсии у пользователей из США с устройствами Mac;
#         - при этом они показывают наихудшие показатели по удержанию.
#
# Анализ окупаемости рекламы показал следующие результаты:
# - ROI достигает 80% -> реклама не окупается;
# - по устройствам окупаются польователи только PC, при этом пользователи с наибольшей клиенсткой базой на Android и IOs не окупаются вообще;
# - аналогичная ситуация (как и для пользователей с Android и IOs) и с каналами привлечения пользвателей, а именно для TipTop , FaceBoom , AddNonSense.
#
# Окончательным выводом почеркну, что пользователи из европейских стран стабильно окупаются, несмотря на то, что данных пользователей значительно меньше, чем в США, которые являются убыточными.

# %% [markdown]
# ### Общие выводы

# %% [markdown]
# В данной работе были проанализированы данные о пользователях по приложению Procrastinate+ c 1 мая по 27 октября 2019 года. Обозначим несколько общих данных:
# - за данный период компания инвестировала в рекламу -> 105497.3 долларов;
# - большая часть пользователей приложения проживает в США;
# - основным использующимся устройством являются следующие девайсы -> IPhone и Mac.
#
# По проведенному анализу по вышеописанным данным можно сделать только неутешительные выводы, так как не смотря на большое количество пользователей из США с устройствам на платформе IOS показатели конверсии и их удержания являются убычточными, одной из причин является дорогая стоимость привлечения. Лучшими показателями для приложения являются пользователи из европейских стран, так как они не смотря на то, что они в подавляющем меньшенстве, окупались на всем предоставленном периоде.
#
# Выделим возможные причины неэффективности привлечения пользователей:
# - стоимость на привлечение пользователей завышена, несмотря на их подавляющее большинство -> данные расходы не окупились;
# - большие затраты также направлены на канал привлечения TipTop, которые также не окупились, несмотря на хорошую конверсию;
# - наблюдается большее внимание на рекламные вложения для устройств IPhone и MAC.
#
# Определим рекомендации для отдела маркетинга:
# - стоит обратить внимание на каналы привлечения LambdaMediaAds и RocketSuperAds - у данных каналов хорошие показатели конверсии и удержания, а также ROI;
# - уделить внимание устройствам PC и Android плавным и аккуратными действиями, так как сейчас их ROI выше за счет более низкого CAC, с последующим отслеживанием показателей при привлечении дополнительных инвестий;
# - необходимо обратить внимание на рынок Европейских стран, так как при анализе данные страны показали отличные показатели ROI.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод, молодец, что в итоговом выводе сформулировал рекомендации для отдела маркетинга: про каналы, от которых стоит отказаться ты упомянул, также предложил альтернативные каналы( LambdaMediaAds и RocketSuperAds), по которому показатели конверсии, удержания и ROI на приемлемом уровне. Как думаешь, а канал `Yrabbit` подойдет?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Я думаю что канал Yrabbit нужно на данный момент поддерживать в текущем состоянии и планомерно по данному каналу увеличивать привлечения, так как у данного канала самая лучшая окупаемость и динамика удержания хорошая, на протяжении всего периода пользователи удерживаются выше линии окупаемости.</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Я бы не рекомендовал вкладываться в канал `Yrabbit`. Почему я так думаю: да, канал сейчас окупается, потому что там низкий CAC. Фактически мы сейчас сильно много не платим за новых клиентов (CAC = 0,21) . И уже на этих клиентах (которые обошлись нам недорого) мы сможем спрогнозировать будущую картину. Они имеют низкую конвертируемость и сильно падающее удержание на последних днях горизонта. Т.е. можно сделать вывод, что им не интересно наше приложение. Возможно, это просто не наша аудитория. Они не заинтересованы в нашем приложении

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Вводная часть
#
# 2) Отсутствует проверка на пропуски и дубликаты
#
# 3) Визуализировать динамику расходов по каналам, по месяцам и неделям (2 графика)
#
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b>
# Саш, спасибо большое тебе за конструктивную критику и советы с полезными ссылками. В дальнейшем буду стараться использовать новые знания более обширно. Постарался все твои замечания учесть.</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
#
# Денис, рад тебя видеть =) Спасибо тебе за обратную связь и крутой проект ^^
#
# ---
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличный метериал про продуктовую аналитику Дмитрия Животворева.
#
# https://www.youtube.com/watch?v=Vy_rq-x9QEo
